# %% [markdown]
# ### Regression
#
# $$\large y_i = \Phi_1 x_i + \Phi_0$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 100
x = np.arange(n)
y = np.random.rand(n)*n/2 + x

# %% [markdown]
# $$\large \Phi_1 = \frac{\sum_i{(x_i - \bar x)(y_i - \bar y)}}{\sum_i {(x_i - \bar x)^2}}$$

# %% [markdown]
# $$\large \Phi_0 = \bar y -  \bar x \Phi_1 $$

# %%
b1 = np.sum((x - np.mean(x))*(y - np.mean(y)))/np.sum((x - np.mean(x))**2)
b0 = np.mean(y) - b1*np.mean(x)

# %%
plt.plot(x,y,'.')
plt.plot(x,b1*x+b0,'r-')
plt.show()

# %%
A = np.vstack([x, np.ones(x.shape[0])]).T

np.testing.assert_array_almost_equal(np.linalg.lstsq(A,y)[0], np.array([b1,b0]))

# %%
plt.plot(x,y,'b.')
plt.plot(x, np.linalg.lstsq(A,y)[0][0]*x + np.linalg.lstsq(A,y)[0][1], 'g')
plt.show()
